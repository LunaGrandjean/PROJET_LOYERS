# %%
import pandas as pd
import chardet
from pandas_profiling import ProfileReport
import glob

# %%
file_name = "Base_OP_2022_Nationale.csv" 

with open(file_name, 'rb') as file:   #Détecter l'encoding 
    result = chardet.detect(file.read()) 
    
df = pd.read_csv(file_name, encoding=result['encoding'], sep=';')

# %%
df.head()
# Out:
#   Observatory  Data_year           agglomeration Zone_complementaire  \
# 0       B2900       2022  Agglomération de Brest                 NaN
# 1       B2900       2022  Agglomération de Brest                 NaN
# 2       B2900       2022  Agglomération de Brest                 NaN
# 3       B2900       2022  Agglomération de Brest                 NaN
# 4       B2900       2022  Agglomération de Brest                 NaN
#
#   Type_habitat epoque_construction_homogene anciennete_locataire_homogene  \
# 0          NaN                          NaN                           NaN
# 1          NaN                          NaN                           NaN
# 2          NaN                          NaN                           NaN
# 3          NaN                          NaN                           NaN
# 4          NaN                          NaN                           NaN
#
#   nombre_pieces_homogene loyer_1_decile loyer_1_quartile  ...  \
# ...

# %%
file_pattern = "Base_OP_*_Nationale.csv"
files = glob.glob(file_pattern)

all_dataframes = []

for file_name in files:
    with open(file_name, 'rb') as file:
        result = chardet.detect(file.read())
    
    df = pd.read_csv(file_name, encoding=result['encoding'], sep=';')
    all_dataframes.append(df)

# Concaténer tous les dataframes
combined_df = pd.concat(all_dataframes, ignore_index=True)

# %%
combined_df.head()
# Out:
#   Observatory  Data_year                 agglomeration Zone_complementaire  \
# 0       B0600       2014  Agglomération de Nice-Menton                 NaN
# 1       B0600       2014  Agglomération de Nice-Menton                 NaN
# 2       B0600       2014  Agglomération de Nice-Menton                 NaN
# 3       B0600       2014  Agglomération de Nice-Menton                 NaN
# 4       B0600       2014  Agglomération de Nice-Menton                 NaN
#
#   Type_habitat epoque_construction_homogene anciennete_locataire_homogene  \
# 0          NaN                          NaN                           NaN
# 1          NaN                          NaN                           NaN
# 2          NaN                          NaN                           NaN
# 3          NaN                          NaN                           NaN
# 4          NaN                          NaN                           NaN
#
#   nombre_pieces_homogene loyer_1_decile loyer_1_quartile  ...  \
# ...

# %%
ProfileReport(combined_df)
